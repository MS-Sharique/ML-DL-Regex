# %% [markdown]
# ## Task 4
# ## Machine Learning and Deep learning Summer Internship
# ## Registration id -SIRSS2290
# ## Mohammad Sharique Salman
#
# ## EDA on IPL dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing Data of Each ball

# %%
df = pd.read_csv('deliveries.csv')

# %% [markdown]
# ## Having a look at our data

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
filt = df['batsman'] == 'DA Warner'
df_warner = df[filt]
df_warner.shape
# Out:
# (2902, 21)

# %% [markdown]
# ## Visualizing how David Warner get's out using a Pie plot.

# %%
 df_warner['dismissal_kind'].value_counts().plot.pie()

# %%
len(df_warner[df_warner['batsman_runs']==4])
# Out:
# 401

# %%
def count(df,runs):
    return len(df_warner[df_warner['batsman_runs']==runs])*runs

# %%
print(count(df_warner,1))
# Out:
# 997

# %% [markdown]
# ## Visualizing how Warner scores most of his runs

# %%
slices =[997,1604,960]
labels = [1,4,6]
explode =[0.,0.1,0]
plt.pie(slices, labels = labels, autopct='%1.1f%%', explode = explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x1ab8b731748>,
# ...
#  [Text(0.701226217262596, 0.8475150690244927, '1'),
#   Text(-1.1993607480544137, -0.03916370802614444, '4'),
#   Text(0.7285125276687221, -0.8241780736162116, '6')],
#  [Text(0.3824870275977796, 0.4622809467406323, '28.0%'),
#   Text(-0.6996271030317414, -0.02284549634858425, '45.0%'),
#   Text(0.39737046963748474, -0.4495516765179336, '27.0%')])

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# ## Assigning shorthands for each Team name

# %%
df['bowling_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiant', 'Mumbai Indians',
#        'Kolkata Knight Riders', 'Gujarat Lions', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Deccan Chargers', 'Kochi Tuskers Kerala', 'Pune Warriors',
#        'Rising Pune Supergiants'], dtype=object)

# %%
Teams = {
    'Royal Challengers Bangalore':'RCB', 'Sunrisers Hyderabad':'SRH',
       'Rising Pune Supergiant':'RPS', 'Mumbai Indians':'MI',
       'Kolkata Knight Riders':'KKR', 'Gujarat Lions':'GL', 'Kings XI Punjab':'KXIP',
       'Delhi Daredevils':'DD', 'Chennai Super Kings':'CSK', 'Rajasthan Royals':'RR',
       'Deccan Chargers':'DC', 'Kochi Tuskers Kerala':'KTK', 'Pune Warriors':'PW',
       'Rising Pune Supergiants':'RPS'
}

# %%
df['batting_team'] = df['batting_team'].map(Teams)
df['bowling_team'] = df['bowling_team'].map(Teams)

# %%
df.head()
# Out:
#    match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0         1       1          SRH          RCB     1     1  DA Warner
# 1         1       1          SRH          RCB     1     2  DA Warner
# 2         1       1          SRH          RCB     1     3  DA Warner
# 3         1       1          SRH          RCB     1     4  DA Warner
# 4         1       1          SRH          RCB     1     5  DA Warner
#
#   non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0    S Dhawan  TS Mills              0  ...         0            0
# 1    S Dhawan  TS Mills              0  ...         0            0
# 2    S Dhawan  TS Mills              0  ...         0            0
# 3    S Dhawan  TS Mills              0  ...         0            0
# 4    S Dhawan  TS Mills              0  ...         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 0            0             0             0           0           0
# ...

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
runs = df.groupby(['match_id', 'inning', 'batting_team'])['total_runs'].sum().reset_index()
runs.drop('match_id',axis = 1, inplace = True)
runs
# Out:
#       inning batting_team  total_runs
# 0          1          SRH         207
# 1          2          RCB         172
# 2          1           MI         184
# 3          2          RPS         187
# 4          1           GL         183
# 5          2          KKR         184
# 6          1          RPS         163
# 7          2         KXIP         164
# 8          1          RCB         157
# 9          2           DD         142
# 10         1           GL         135
# 11         2          SRH         140
# 12         1          KKR         178
# 13         2           MI         180
# 14         1          RCB         148
# 15         2         KXIP         150
# 16         1           DD         205
# 17         2          RPS         108
# 18         1          SRH         158
# 19         2           MI         159
# 20         1         KXIP         170
# 21         2          KKR         171
# 22         1          RCB         142
# 23         2           MI         145
# ...

# %%
inning1 = runs[runs['inning'] == 1]
inning2 = runs[runs['inning'] == 2]

# %% [markdown]
# ## Taking a look at team totals in both the innings using boxplot, to get a better understanding of which team scores higher throughout the tournament.

# %%
sns.boxplot(x ='batting_team',y = 'total_runs', data = inning1)

# %%
sns.boxplot(x ='batting_team',y = 'total_runs', data = inning2)

# %%
high_scores = df.groupby(['match_id','inning','batting_team','bowling_team'])['total_runs'].sum().reset_index()

# %%
score_200 = high_scores[high_scores['total_runs'] >= 200]

# %%
score_200.head()
# Out:
#     match_id  inning batting_team bowling_team  total_runs
# 0          1       1          SRH          RCB         207
# 16         9       1           DD          RPS         205
# 38        20       1          RCB           GL         213
# 62        32       1          SRH         KXIP         207
# 72        36       1          SRH          KKR         209

# %% [markdown]
# ## Taking a look at which team scores 200+ as team totals throughout the tournament with the frequencies of each team.

# %%
sns.countplot(score_200['batting_team'])

# %% [markdown]
# ## The Bowling teams that conceded 200+ runs in an innings

# %%
sns.countplot(score_200['bowling_team'])

# %%
balls = df.groupby('batsman')['ball'].count().reset_index()

# %%
runs_total = df.groupby('batsman')['batsman_runs'].sum().reset_index()
runs_total.head(20)
# Out:
#             batsman  batsman_runs
# 0    A Ashish Reddy           280
# 1        A Chandila             4
# 2          A Chopra            53
# 3       A Choudhary            25
# 4        A Flintoff            62
# 5          A Kumble            35
# 6          A Mishra           340
# 7          A Mithun            34
# 8          A Mukund            19
# 9           A Nehra            41
# 10          A Singh             2
# 11        A Symonds           974
# 12         A Uniyal             4
# 13          A Zampa             5
# 14      AA Bilakhia            69
# 15        AA Chavan            12
# 16  AA Jhunjhunwala           217
# 17        AA Noffke             9
# 18       AB Agarkar           179
# 19        AB Barath            42

# %%
fours =df[df['batsman_runs']==4]
fours.head(20)
# Out:
#      match_id  inning batting_team bowling_team  over  ball        batsman  \
# 2           1       1          SRH          RCB     1     3      DA Warner
# 8           1       1          SRH          RCB     2     2      DA Warner
# 13          1       1          SRH          RCB     2     7   MC Henriques
# 30          1       1          SRH          RCB     5     5   MC Henriques
# 32          1       1          SRH          RCB     6     1       S Dhawan
# 33          1       1          SRH          RCB     6     2       S Dhawan
# 35          1       1          SRH          RCB     6     4       S Dhawan
# 36          1       1          SRH          RCB     6     5       S Dhawan
# 63          1       1          SRH          RCB    11     2       S Dhawan
# 72          1       1          SRH          RCB    12     5   Yuvraj Singh
# 74          1       1          SRH          RCB    13     1   Yuvraj Singh
# ...

# %%
runs_4 = fours.groupby('batsman')['batsman_runs'].count().reset_index()
runs_4.columns = ['batsman','4s']
runs_4
# Out:
#               batsman   4s
# 0      A Ashish Reddy   16
# 1            A Chopra    7
# 2         A Choudhary    1
# 3          A Flintoff    5
# 4            A Kumble    3
# 5            A Mishra   27
# 6            A Mithun    4
# 7            A Mukund    1
# 8             A Nehra    3
# 9           A Symonds   74
# 10            A Zampa    1
# 11        AA Bilakhia    5
# 12          AA Chavan    2
# 13    AA Jhunjhunwala   19
# 14          AA Noffke    1
# 15         AB Agarkar   13
# 16          AB Barath    5
# 17           AB Dinda    2
# 18        AB McDonald    9
# 19     AB de Villiers  287
# 20        AC Blizzard   21
# 21       AC Gilchrist  239
# 22          AC Thomas    1
# 23           AC Voges   15
# 24     AD Mascarenhas    5
# 25         AD Mathews   44
# 26            AD Nath    1
# 27         AD Russell   48
# 28         AG Murtaza    1
# 29        AG Paunikar    9
# ..                ...  ...
# 338        TM Dilshan  140
# 339           TM Head   12
# ...

# %%
six =df[df['batsman_runs']==6]
six
# Out:
#         match_id  inning batting_team bowling_team  over  ball       batsman  \
# 10             1       1          SRH          RCB     2     4     DA Warner
# 47             1       1          SRH          RCB     8     4  MC Henriques
# 75             1       1          SRH          RCB    13     2  Yuvraj Singh
# 89             1       1          SRH          RCB    15     3  Yuvraj Singh
# 91             1       1          SRH          RCB    15     5  MC Henriques
# 105            1       1          SRH          RCB    18     1      DJ Hooda
# 115            1       1          SRH          RCB    19     3  Yuvraj Singh
# 121            1       1          SRH          RCB    20     3   BCJ Cutting
# 124            1       1          SRH          RCB    20     6   BCJ Cutting
# 142            1       2          RCB          SRH     3     6      CH Gayle
# 144            1       2          RCB          SRH     4     2      CH Gayle
# ...

# %%
runs_6 = six.groupby('batsman')['batsman_runs'].count().reset_index()
runs_6.columns = ['batsman','6s']
runs_6
# Out:
#              batsman   6s
# 0     A Ashish Reddy   15
# 1        A Choudhary    1
# 2         A Flintoff    2
# 3           A Mishra    5
# 4           A Mithun    1
# 5            A Nehra    1
# 6          A Symonds   41
# 7    AA Jhunjhunwala    5
# 8         AB Agarkar    5
# 9          AB Barath    1
# 10       AB McDonald    4
# 11    AB de Villiers  158
# 12       AC Blizzard    2
# 13      AC Gilchrist   92
# 14         AC Thomas    1
# 15          AC Voges    3
# 16    AD Mascarenhas    1
# 17        AD Mathews   29
# 18        AD Russell   37
# 19          AJ Finch   59
# 20            AJ Tye    3
# 21        AL Menaria   18
# 22          AM Nayar   20
# 23         AM Rahane   60
# 24          AN Ahmed    1
# 25           AP Dole    1
# 26       AP Majumdar    2
# 27           AP Tare   11
# 28          AR Patel   28
# 29           AS Raut    7
# ..               ...  ...
# 271      Sunny Singh    1
# 272      T Henderson    1
# 273          T Kohli    1
# ...

# %% [markdown]
# ## Now looking at each player, total runs scored, balls played, and boundaries.

# %%
player = pd.concat([runs_total, balls.iloc[:,1], runs_4.iloc[:,1], runs_6.iloc[:,1]], axis=1)
player
# Out:
#                   batsman  batsman_runs  ball     4s     6s
# 0          A Ashish Reddy           280   196   16.0   15.0
# 1              A Chandila             4     7    7.0    1.0
# 2                A Chopra            53    75    1.0    2.0
# 3             A Choudhary            25    20    5.0    5.0
# 4              A Flintoff            62    57    3.0    1.0
# 5                A Kumble            35    49   27.0    1.0
# 6                A Mishra           340   382    4.0   41.0
# 7                A Mithun            34    26    1.0    5.0
# 8                A Mukund            19    23    3.0    5.0
# 9                 A Nehra            41    63   74.0    1.0
# 10                A Singh             2    10    1.0    4.0
# 11              A Symonds           974   781    5.0  158.0
# 12               A Uniyal             4     7    2.0    2.0
# 13                A Zampa             5     8   19.0   92.0
# 14            AA Bilakhia            69    88    1.0    1.0
# ...

# %% [markdown]
# ## Replacing NA values with 0

# %%
player.fillna(0,inplace = True)

# %%
player
# Out:
#                   batsman  batsman_runs  ball     4s     6s
# 0          A Ashish Reddy           280   196   16.0   15.0
# 1              A Chandila             4     7    7.0    1.0
# 2                A Chopra            53    75    1.0    2.0
# 3             A Choudhary            25    20    5.0    5.0
# 4              A Flintoff            62    57    3.0    1.0
# 5                A Kumble            35    49   27.0    1.0
# 6                A Mishra           340   382    4.0   41.0
# 7                A Mithun            34    26    1.0    5.0
# 8                A Mukund            19    23    3.0    5.0
# 9                 A Nehra            41    63   74.0    1.0
# 10                A Singh             2    10    1.0    4.0
# 11              A Symonds           974   781    5.0  158.0
# 12               A Uniyal             4     7    2.0    2.0
# 13                A Zampa             5     8   19.0   92.0
# 14            AA Bilakhia            69    88    1.0    1.0
# ...

# %% [markdown]
# ## Adding Batsman Strike Rate to the data

# %%
player['strike_rate'] = (player['batsman_runs']/player['ball'])*100

# %%
player
# Out:
#                   batsman  batsman_runs  ball     4s     6s  strike_rate
# 0          A Ashish Reddy           280   196   16.0   15.0   142.857143
# 1              A Chandila             4     7    7.0    1.0    57.142857
# 2                A Chopra            53    75    1.0    2.0    70.666667
# 3             A Choudhary            25    20    5.0    5.0   125.000000
# 4              A Flintoff            62    57    3.0    1.0   108.771930
# 5                A Kumble            35    49   27.0    1.0    71.428571
# 6                A Mishra           340   382    4.0   41.0    89.005236
# 7                A Mithun            34    26    1.0    5.0   130.769231
# 8                A Mukund            19    23    3.0    5.0    82.608696
# 9                 A Nehra            41    63   74.0    1.0    65.079365
# 10                A Singh             2    10    1.0    4.0    20.000000
# 11              A Symonds           974   781    5.0  158.0   124.711908
# ...

# %% [markdown]
# # Thank you
